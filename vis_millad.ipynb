# %%
import pandas as pd
from rdkit import Chem
from rdkit.Chem import Draw

# %%
df = pd.read_csv("examples/test_millad_2/pop.csv")
gen_mols = [Chem.MolFromSmiles(smi) for smi in df.smiles]

# %%
Chem.Draw.MolsToGridImage(gen_mols, molsPerRow=4, subImgSize=(400,400))
